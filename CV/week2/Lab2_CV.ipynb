# %% [markdown]
# # Computer Vision
# **Lab-1 12-01-2022**
# ---
# #Aishwar Pathak BT20HCS132

# %%
import numpy
import matplotlib.pyplot as plt
import scipy
from scipy import ndimage
from skimage import io
import cv2

# %%
image = io.imread("1.jpg")
plt.imshow(image) 
print('size: {} shape: {}'.format(image.size, image.shape))
# Out:
# size: 2150400 shape: (700, 1024, 3)

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.title('Gray Scale Training Image')
plt.imshow(training_gray, cmap = 'gray')

# %%
import cv2 
import matplotlib.pyplot as plt
# %matplotlib inline
#reading image
img1 = cv2.imread('1.jpg')  
gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
#keypoints
sift = cv2.xfeatures2d.SIFT_create()
keypoints_1, descriptors_1 = sift.detectAndCompute(img1,None)
img_1 = cv2.drawKeypoints(gray1,keypoints_1,img1)
plt.imshow(img_1)
print("\nNumber of keypoints Detected: ", len(keypoints))
# Out:
# Number of keypoints Detected:  470

# %% [markdown]
# Oriented FAST and Rotated BRIEF (ORB)

# %%
import copy
plt.rcParams['figure.figsize'] = [14.0, 7.0]

orb = cv2.ORB_create(500, 2.0)

keypoints, descriptor = orb.detectAndCompute(training_gray, None)
keyp_without_size = copy.copy(training_image)
keyp_with_size = copy.copy(training_image)
cv2.drawKeypoints(training_image, keypoints, keyp_without_size, color = (0, 255, 0))
cv2.drawKeypoints(training_image, keypoints, keyp_with_size, flags = cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
plt.subplot(121)
plt.title('Keypoints Without Size or Orientation')
plt.imshow(keyp_without_size)
plt.subplot(122)
plt.title('Keypoints With Size and Orientation')
plt.imshow(keyp_with_size)
plt.show()
print("\nNumber of keypoints Detected: ", len(keypoints))
# Out:
# Number of keypoints Detected:  470

# %% [markdown]
# Feature Matching using brute force approach

# %%
im1= cv2.imread('1.jpg')
im2= cv2.imread('2.jpg')
sift = cv2.xfeatures2d.SIFT_create()
kp1, des1 = sift.detectAndCompute(im1, None)
kp2, des2 = sift.detectAndCompute(im2, None)

# %%
img1_feature = cv2.drawKeypoints(im1,kp1, None)
plt.imshow(img1_feature)

# %%
img2_feature = cv2.drawKeypoints(im2,kp2, None)
plt.imshow(img2_feature)

# %%
print(len(kp1))
# Out:
# 3155

# %%
for d in des1:
  print(d)
# Out:
# Streaming output truncated to the last 5000 lines.
# [  9.   2.   2.   1.  12.  33.  26.  51.  14.  35.  31.   6.  22.  33.
#    9.   3.  52.  18.   6.   1.   2.   8.  15.  65.  13.   2.   1.  20.
#   85.   9.   5.  36.   2.   3.  62.  71.  27.  31.  20.  25.  46.  42.
#   36.  95.  85.  35.   1.   1. 121.  60.   4.  19.  14.   0.   0.  27.
#   21.   2.   1. 107. 121.   1.   1.  13.   0.   0.  53. 121.  34.   9.
#    3.   0.  97.  12.  47.  70.   6.   4.   4.  36. 121.  18.   4.  35.
#   32.  21.   9.  83.  10.   3.   7.  83.  91.  26.  11.  21.   0.   0.
#    0.  15.  33. 103.  22.   0. 121.   3.   0.   1.   5.  23.  12.  65.
#  121.  15.   9.  59.  44.  30.  12.  84.   1.   1.  12. 100.  82.  30.
#    3.   3.]
# [  0.  16.  42.  34.  24.  14.   3.   0.  93.   7.   6.  19.  21.   4.
#    2.  23. 158.   3.   0.   0.   0.   0.   0.  77.  96.   4.   0.   0.
#    0.   0.   0.  17.  11.  44.  29.   8.   4.   4.  33.  24. 151.  14.
# ...

# %%
queryImg = cv2.imread(r'1.jpg')
trainImg = cv2.imread(r'2.jpg')

print('Query image -> size: {} shape: {}'.format(queryImg.size, queryImg.shape))
print('Train image -> size: {} shape: {}'.format(trainImg.size, trainImg.shape))
# Out:
# Query image -> size: 2150400 shape: (700, 1024, 3)
# Train image -> size: 901812 shape: (446, 674, 3)

# %%
bf=cv2.BFMatcher(cv2.NORM_L2, crossCheck= True)
matches = bf.match(des1, des2)
print(len(matches))
for i in matches:
  print(m.distance)
# Out:
# 516
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# 269.770263671875
# ...

# %% [markdown]
# Grey Scale conversion

# %%
grayQuery = cv2.cvtColor(queryImg, cv2.COLOR_BGR2GRAY)
grayTrain = cv2.cvtColor(trainImg, cv2.COLOR_BGR2GRAY)
plt.imshow(grayQuery)

# %%
plt.imshow(grayTrain)

# %%
#creating ORB detector
orb = cv2.ORB_create()
#finding keypoints and descriptors
kpQuery, descQuery = orb.detectAndCompute(grayQuery, None)
kpTrain, descTrain = orb.detectAndCompute(grayTrain, None)
matcher = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
print('Created Brute-Force matcher')
# Out:
# Created Brute-Force matcher

# %%
matches = matcher.match(descQuery, descTrain)
matches = sorted(matches, key=lambda x:x.distance)

# %%
result = cv2.drawMatches(grayQuery, kpQuery, grayTrain, kpTrain, matches[:100], 
                         None, (255, 0, 0), flags=2)
cv2.imwrite('3.jpg', result)
plt.imshow(result)
plt.show()
